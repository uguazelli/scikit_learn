# %% [markdown]
# <a href="https://colab.research.google.com/github/uguazelli/scikit_learn/blob/main/knn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sn

# %%
iris = load_iris()

# %%
# iris.data
pd.DataFrame(iris.data, columns = iris.feature_names)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
# iris.target
pd.DataFrame(iris.target, columns = ['species'])
# Out:
#      species
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# 145        2
# 146        2
# 147        2
# 148        2
# 149        2
#
# [150 rows x 1 columns]

# %%
xtr, xte, ytr, yte = train_test_split(iris['data'], iris['target'], test_size=0.3, random_state=42)

# %%
sn.scatterplot(x=xtr[:, 0], y=xtr[:, 1], hue=ytr)
# Out:
# <Axes: >

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(xtr, ytr)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(xte)
accuaracy = accuracy_score(yte, y_pred)
print(accuaracy)
# Out:
# 1.0

# %%
cm = confusion_matrix(yte, y_pred)
print(cm)
# Out:
# [[19  0  0]
#  [ 0 13  0]
#  [ 0  0 13]]

# %%
df = pd.DataFrame(iris.data, columns = iris.feature_names)
#print(df.head())

print(df.iloc[0])
# Out:
# sepal length (cm)    5.1
# sepal width (cm)     3.5
# petal length (cm)    1.4
# petal width (cm)     0.2
# Name: 0, dtype: float64

# %%
result = knn.predict(df.iloc[0].values.reshape(1, -1))
print(result)
# Out:
# [0]
